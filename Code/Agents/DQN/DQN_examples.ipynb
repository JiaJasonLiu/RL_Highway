# %% [markdown]
# ## Running Their DQN
#
# ## Installations

# %%
# !pip install highway-env
# !pip install --upgrade sympy torch
# !git+https://github.com/DLR-RM/stable-baselines3
# Out:
# Requirement already satisfied: highway-env in /opt/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (3.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.7.3)
# Requirement already satisfied: pygame>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (2.6.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.21.5)
# Requirement already satisfied: gymnasium>=1.0.0a2 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.0.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.4.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (4.12.2)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium>=1.0.0a2->highway-env) (3.21.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (0.11.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->highway-env) (2021.3)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (1.13.1)
# Collecting sympy
#   Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 4.8 MB/s eta 0:00:01
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.9/site-packages (2.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from sympy) (1.2.1)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.9/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.9/site-packages (from torch) (2.7.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from torch) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch) (2.0.1)
# zsh:1: no such file or directory: git+https://github.com/DLR-RM/stable-baselines3

# %%
import gymnasium as gym
import highway_env
from stable_baselines3 import DQN
import torch


# Visualization utils
# %load_ext tensorboard
import sys
from tqdm.notebook import trange
# !pip install tensorboardx gym pyvirtualdisplay
# doesn't work cause not linux
# !apt-get install -y xvfb ffmpeg
# !git clone https://github.com/Farama-Foundation/HighwayEnv.git 2> /dev/null
# sys.path.insert(0, '/content/HighwayEnv/scripts/')
# from utils import record_videos, show_videos

# %%
# for MLP
# config = {
#     "observation": {
#         "type": "Kinematics",
#         "vehicles_count": 15,
#         "features": ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"],
#         "features_range": {
#             "x": [-100, 100],
#             "y": [-100, 100],
#             "vx": [-20, 20],
#             "vy": [-20, 20]
#         },
#         "absolute": False,
#         "order": "sorted"
#     }
# }

# # For CNN
config={
    "observation": {
        "type": "GrayscaleObservation",
        "observation_shape": (128, 64),
        "stack_size": 4,
        "weights": [0.2989, 0.5870, 0.1140],  # weights for RGB conversion
        "scaling": 1.75,
    },
}

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array', config=config)
print(env.unwrapped.config)
mps_device = torch.device("mps")

model = DQN('CnnPolicy',  env,
            # 'highway-fast-v0',
                # policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log='highway_dqn/')
model.learn(int(2e4)) # 20,000
# Out:
# {'observation': {'type': 'GrayscaleObservation', 'observation_shape': (128, 64), 'stack_size': 4, 'weights': [0.2989, 0.587, 0.114], 'scaling': 1.75}, 'action': {'type': 'DiscreteMetaAction'}, 'simulation_frequency': 5, 'policy_frequency': 1, 'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle', 'screen_width': 600, 'screen_height': 150, 'centering_position': [0.3, 0.5], 'scaling': 5.5, 'show_trajectories': False, 'render_agent': True, 'offscreen_rendering': False, 'manual_control': False, 'real_time_rendering': False, 'lanes_count': 3, 'vehicles_count': 20, 'controlled_vehicles': 1, 'initial_lane_id': None, 'duration': 30, 'ego_spacing': 1.5, 'vehicles_density': 1, 'collision_reward': -1, 'right_lane_reward': 0.1, 'high_speed_reward': 0.4, 'lane_change_reward': 0, 'reward_speed_range': [20, 30], 'normalize_reward': True, 'offroad_terminal': False}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 41       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 8.66     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 41       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 41       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 7.75     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 41       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 39       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 205      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0851   |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 7.49     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 26       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 247      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0241   |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.11     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 20       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 307      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0724   |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.13     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 17       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 350      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0339   |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.82     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 15       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 423      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 222      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.69     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 15       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 460      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.301    |
# |    n_updates        | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.88     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 14       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 516      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.264    |
# |    n_updates        | 315      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 13       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 541      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0947   |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.28     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 13       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 571      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.264    |
# |    n_updates        | 370      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 13       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 613      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.289    |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 12       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 658      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.289    |
# |    n_updates        | 457      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.29     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 12       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 708      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.19     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 12       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 742      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.284    |
# |    n_updates        | 541      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.17     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 12       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 785      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.377    |
# |    n_updates        | 584      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.17     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 12       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 831      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.662    |
# |    n_updates        | 630      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.32     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 12       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 889      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0412   |
# |    n_updates        | 688      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.16     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 916      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.327    |
# |    n_updates        | 715      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11       |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 979      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.652    |
# |    n_updates        | 778      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.42     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 1033     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.625    |
# |    n_updates        | 832      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.26     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 1060     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.556    |
# |    n_updates        | 859      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.38     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 1116     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.416    |
# |    n_updates        | 915      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 1151     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.226    |
# |    n_updates        | 950      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.25     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 1196     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.328    |
# |    n_updates        | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.19     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 1220     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.134    |
# |    n_updates        | 1019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.37     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11       |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 1283     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0279   |
# |    n_updates        | 1082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11       |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 1329     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.216    |
# |    n_updates        | 1128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.57     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11       |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 1389     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.301    |
# |    n_updates        | 1188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 1423     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.287    |
# |    n_updates        | 1222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11       |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 1450     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 1249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11       |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 1494     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.422    |
# |    n_updates        | 1293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11       |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 1545     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 1344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.06     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 10       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.365    |
# |    n_updates        | 1399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.11     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 10       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 1634     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 1433     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 10       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 1697     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.238    |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.48     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 10       |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 1754     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.6      |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 10       |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 1813     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0994   |
# |    n_updates        | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.49     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 10       |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 1849     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.4      |
# |    n_updates        | 1648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.51     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 10       |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 1888     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.307    |
# |    n_updates        | 1687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 10       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 1909     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.299    |
# |    n_updates        | 1708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.29     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 10       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 1949     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0494   |
# |    n_updates        | 1748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.2      |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 1997     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.393    |
# |    n_updates        | 1796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 2029     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 1828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 7.96     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 2055     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.295    |
# |    n_updates        | 1854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.75     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10       |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 2081     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.381    |
# |    n_updates        | 1880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.02     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10       |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 2144     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.398    |
# |    n_updates        | 1943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.11     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 2216     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0071   |
# |    n_updates        | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.18     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10       |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 2260     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.487    |
# |    n_updates        | 2059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.04     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10       |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 2284     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0239   |
# |    n_updates        | 2083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.17     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10       |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 2324     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.311    |
# |    n_updates        | 2123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.17     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10       |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 2386     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.432    |
# |    n_updates        | 2185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.35     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10       |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 2451     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.307    |
# |    n_updates        | 2250     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.27     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 2496     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.291    |
# |    n_updates        | 2295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.29     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 2533     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.406    |
# |    n_updates        | 2332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.36     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10       |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 2570     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.535    |
# |    n_updates        | 2369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.25     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 2601     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 2400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.27     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 2654     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.426    |
# |    n_updates        | 2453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.1      |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 2685     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.428    |
# |    n_updates        | 2484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.35     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10       |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 2749     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.313    |
# |    n_updates        | 2548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.17     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 2782     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.3      |
# |    n_updates        | 2581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10       |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 2826     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.782    |
# |    n_updates        | 2625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.01     |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 10       |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 2876     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.404    |
# |    n_updates        | 2675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.01     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 10       |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 2910     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 2709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 10       |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 2946     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.304    |
# |    n_updates        | 2745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.09     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 10       |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 2975     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.199    |
# |    n_updates        | 2774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 10       |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 3009     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 2808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 10       |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 3045     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0116   |
# |    n_updates        | 2844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 10       |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 3090     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.515    |
# |    n_updates        | 2889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.3      |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 10       |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 3137     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.431    |
# |    n_updates        | 2936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.37     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 10       |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 3171     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 2970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.12     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 10       |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 3198     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.411    |
# |    n_updates        | 2997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.78     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 10       |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 3224     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.312    |
# |    n_updates        | 3023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.89     |
# |    ep_rew_mean      | 7.66     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 10       |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 3249     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 3048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 10       |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 3294     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.43     |
# |    n_updates        | 3093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.85     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 10       |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 3337     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.016    |
# |    n_updates        | 3136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.78     |
# |    ep_rew_mean      | 7.57     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 10       |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 3364     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.596    |
# |    n_updates        | 3163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 7.29     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 10       |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 3394     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.531    |
# |    n_updates        | 3193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 10       |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 3429     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 3228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.27     |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 10       |
# |    time_elapsed     | 336      |
# |    total_timesteps  | 3460     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.32     |
# |    n_updates        | 3259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.21     |
# |    ep_rew_mean      | 7.13     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 10       |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 3491     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.474    |
# |    n_updates        | 3290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.48     |
# |    ep_rew_mean      | 7.37     |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 10       |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 3549     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.137    |
# |    n_updates        | 3348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 7.36     |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 10       |
# |    time_elapsed     | 351      |
# |    total_timesteps  | 3601     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.44     |
# |    n_updates        | 3400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.69     |
# |    ep_rew_mean      | 7.51     |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 10       |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 3654     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.225    |
# |    n_updates        | 3453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 10       |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 3696     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0172   |
# |    n_updates        | 3495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 7.38     |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 10       |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 3732     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 3531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 10       |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 3794     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.394    |
# |    n_updates        | 3593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 7.3      |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 10       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 3821     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.214    |
# |    n_updates        | 3620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 7.33     |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 10       |
# ...
# |    time_elapsed     | 1544     |
# |    total_timesteps  | 17470    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 17269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 11       |
# |    time_elapsed     | 1549     |
# |    total_timesteps  | 17523    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 17322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 11       |
# |    time_elapsed     | 1551     |
# |    total_timesteps  | 17548    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0707   |
# |    n_updates        | 17347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 11       |
# |    time_elapsed     | 1559     |
# |    total_timesteps  | 17642    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0279   |
# |    n_updates        | 17441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 11       |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 17723    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 17522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 11       |
# |    time_elapsed     | 1575     |
# |    total_timesteps  | 17843    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.06     |
# |    n_updates        | 17642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 11       |
# |    time_elapsed     | 1581     |
# |    total_timesteps  | 17930    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0463   |
# |    n_updates        | 17729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 11       |
# |    time_elapsed     | 1586     |
# |    total_timesteps  | 17992    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 17791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 11       |
# |    time_elapsed     | 1595     |
# |    total_timesteps  | 18103    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.263    |
# |    n_updates        | 17902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 11       |
# |    time_elapsed     | 1602     |
# |    total_timesteps  | 18184    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 17983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 11       |
# |    time_elapsed     | 1607     |
# |    total_timesteps  | 18250    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0292   |
# |    n_updates        | 18049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 11       |
# |    time_elapsed     | 1614     |
# |    total_timesteps  | 18340    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.185    |
# |    n_updates        | 18139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 11       |
# |    time_elapsed     | 1621     |
# |    total_timesteps  | 18425    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.351    |
# |    n_updates        | 18224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 11       |
# |    time_elapsed     | 1628     |
# |    total_timesteps  | 18513    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0968   |
# |    n_updates        | 18312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 11       |
# |    time_elapsed     | 1636     |
# |    total_timesteps  | 18603    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.181    |
# |    n_updates        | 18402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 11       |
# |    time_elapsed     | 1645     |
# |    total_timesteps  | 18713    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.219    |
# |    n_updates        | 18512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 11       |
# |    time_elapsed     | 1653     |
# |    total_timesteps  | 18823    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.146    |
# |    n_updates        | 18622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 11       |
# |    time_elapsed     | 1661     |
# |    total_timesteps  | 18925    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.309    |
# |    n_updates        | 18724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 11       |
# |    time_elapsed     | 1668     |
# |    total_timesteps  | 19006    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 18805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 11       |
# |    time_elapsed     | 1676     |
# |    total_timesteps  | 19108    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 18907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 11       |
# |    time_elapsed     | 1683     |
# |    total_timesteps  | 19206    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.176    |
# |    n_updates        | 19005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 11       |
# |    time_elapsed     | 1689     |
# |    total_timesteps  | 19284    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.178    |
# |    n_updates        | 19083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 11       |
# |    time_elapsed     | 1695     |
# |    total_timesteps  | 19355    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 19154    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 11       |
# |    time_elapsed     | 1700     |
# |    total_timesteps  | 19419    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0467   |
# |    n_updates        | 19218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 11       |
# |    time_elapsed     | 1705     |
# |    total_timesteps  | 19483    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.106    |
# |    n_updates        | 19282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 11       |
# |    time_elapsed     | 1711     |
# |    total_timesteps  | 19559    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0851   |
# |    n_updates        | 19358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 11       |
# |    time_elapsed     | 1716     |
# |    total_timesteps  | 19627    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.168    |
# |    n_updates        | 19426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 11       |
# |    time_elapsed     | 1724     |
# |    total_timesteps  | 19718    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0364   |
# |    n_updates        | 19517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 11       |
# |    time_elapsed     | 1730     |
# |    total_timesteps  | 19802    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 19601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 11       |
# |    time_elapsed     | 1738     |
# |    total_timesteps  | 19895    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0831   |
# |    n_updates        | 19694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 11       |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 19959    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.202    |
# |    n_updates        | 19758    |
# ----------------------------------

# %%
model.save("highway_dqn/model")

# %%
# Load and test saved model
model = DQN.load("highway_dqn/model")

env = gym.make("highway-v0", render_mode='rgb_array', config=config)
mps_devce = torch.device("mps")

model = DQN('CnnPolicy', env,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=2e-2,
              buffer_size=15000,
              learning_starts=200,
              batch_size=64,
              gamma=0.8,
              device=mps_device,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")

# while True:
for i in range(100):
  done = truncated = False
  obs, info = env.reset()
  while not (done or truncated):
    action, _states = model.predict(obs, deterministic=True)
    # print(action)
    obs, reward, done, truncated, info = env.step(action)
    env.render()
# Out:
# Using mps device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 22>()
#      26 action, _states = model.predict(obs, deterministic=True)
#      27 # print(action)
# ---> 28 obs, reward, done, truncated, info = env.step(action)
#      29 env.render()
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:240, in AbstractEnv.step(self, action)
#     235     raise NotImplementedError(
#     236         "The road and vehicle must be initialized in the environment implementation"
#     237     )
#     239 self.time += 1 / self.config["policy_frequency"]
# --> 240 self._simulate(action)
#     242 obs = self.observation_type.observe()
#     243 reward = self._reward(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:280, in AbstractEnv._simulate(self, action)
#     275     # Automatically render intermediate simulation steps if a viewer has been launched
#     276     # Ignored if the rendering is done offscreen
#     277     if (
#     278         frame < frames - 1
#     279     ):  # Last frame will be rendered through env.render() as usual
# --> 280         self._automatic_rendering()
#     282 self.enable_auto_render = False
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:340, in AbstractEnv._automatic_rendering(self)
#     338     self._record_video_wrapper.video_recorder.capture_frame()
#     339 else:
# --> 340     self.render()
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:303, in AbstractEnv.render(self)
#     299     self.viewer = EnvViewer(self)
#     301 self.enable_auto_render = True
# --> 303 self.viewer.display()
#     305 if not self.viewer.offscreen:
#     306     self.viewer.handle_events()
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/graphics.py:160, in EnvViewer.display(self)
#     158     if self.env.config["real_time_rendering"]:
#     159         self.clock.tick(self.env.config["simulation_frequency"])
# --> 160     pygame.display.flip()
#     162 if self.SAVE_IMAGES and self.directory:
#     163     pygame.image.save(
#     164         self.sim_surface,
#     165         str(self.directory / f"highway-env_{self.frame}.png"),
#     166     )
#
# KeyboardInterrupt:
