# %% [markdown]
# # RL CW

# %%
# !pip install highway-env
# !pip install git+https://github.com/DLR-RM/stable-baselines3
# Out:
# Requirement already satisfied: highway-env in /opt/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.4.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.7.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (3.5.1)
# Requirement already satisfied: pygame>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (2.6.1)
# Requirement already satisfied: gymnasium>=1.0.0a2 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.9/site-packages (from highway-env) (1.21.5)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (4.12.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium>=1.0.0a2->highway-env) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium>=1.0.0a2->highway-env) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->highway-env) (1.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->highway-env) (2021.3)
# Collecting git+https://github.com/DLR-RM/stable-baselines3
#   Cloning https://github.com/DLR-RM/stable-baselines3 to /private/var/folders/ll/m_r158w50cqfn3ydymrpm7rc0000gn/T/pip-req-build-9pl4dyis
#   Running command git clone -q https://github.com/DLR-RM/stable-baselines3 /private/var/folders/ll/m_r158w50cqfn3ydymrpm7rc0000gn/T/pip-req-build-9pl4dyis
#   Resolved https://github.com/DLR-RM/stable-baselines3 to commit e4f4f123e3b5afa828590b895ec22c7852872fe4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (2.0.0)
# Requirement already satisfied: torch>=1.13 in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (1.13.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (3.5.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (1.4.2)
# Requirement already satisfied: numpy<2.0,>=1.20 in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (1.21.5)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3==2.4.0a11) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3==2.4.0a11) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3==2.4.0a11) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3==2.4.0a11) (0.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium<1.1.0,>=0.29.1->stable_baselines3==2.4.0a11) (3.8.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3==2.4.0a11) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3==2.4.0a11) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->stable_baselines3==2.4.0a11) (2021.3)
# Building wheels for collected packages: stable-baselines3
#   Building wheel for stable-baselines3 (PEP 517) ... done
#   Created wheel for stable-baselines3: filename=stable_baselines3-2.4.0a11-py3-none-any.whl size=183943 sha256=81a8407095d9c91011ceec1c111685ed88f58babb0195eaa0e5b7cba9dd44141
#   Stored in directory: /private/var/folders/ll/m_r158w50cqfn3ydymrpm7rc0000gn/T/pip-ephem-wheel-cache-f_2btvyn/wheels/17/9c/c7/7e4f0c247d9fcdf3b7bdc5606f9a7f691507cc2a068d1509d2
# Successfully built stable-baselines3
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.4.0a11

# %% [markdown]
# ### Running it without Training

# %%
import gymnasium as gym
import highway_env
from matplotlib import pyplot as plt
# %matplotlib inline

env = gym.make('highway-v0', render_mode='rgb_array')
env.reset()
for _ in range(5):
# while True:
    action = env.unwrapped.action_type.actions_indexes["IDLE"]
    obs, reward, done, truncated, info = env.step(action)
    env.render()

# plt.imshow(env.render())
# plt.show()

# %%
import gymnasium as gym
import highway_env
from stable_baselines3 import DQN


# Visualization utils
# %load_ext tensorboard
import sys
from tqdm.notebook import trange
# !pip install tensorboardx gym pyvirtualdisplay
# doesn't work cause not linux
# !apt-get install -y xvfb ffmpeg
# !git clone https://github.com/Farama-Foundation/HighwayEnv.git 2> /dev/null
sys.path.insert(0, '/content/HighwayEnv/scripts/')
# from utils import record_videos, show_videos
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Requirement already satisfied: tensorboardx in /opt/anaconda3/lib/python3.9/site-packages (2.6.2.2)
# Requirement already satisfied: gym in /opt/anaconda3/lib/python3.9/site-packages (0.26.2)
# Requirement already satisfied: pyvirtualdisplay in /opt/anaconda3/lib/python3.9/site-packages (3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.9/site-packages (from tensorboardx) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/lib/python3.9/site-packages (from tensorboardx) (3.20.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from tensorboardx) (1.21.5)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/anaconda3/lib/python3.9/site-packages (from gym) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from gym) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gym) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorboardx) (3.0.4)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 14>()
#      12 get_ipython().system('git clone https://github.com/Farama-Foundation/HighwayEnv.git 2> /dev/null')
#      13 sys.path.insert(0, '/content/HighwayEnv/scripts/')
# ---> 14 from utils import record_videos, show_videos
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ### Learning using existing model

# %%
env = gym.make("highway-fast-v0")
model = DQN('MlpPolicy', env,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model.learn(int(2e4))
# model.save("highway_dqn/model")

# # Load and test saved model
# model = DQN.load("highway_dqn/model")
# while True:
#   done = truncated = False
#   obs, info = env.reset()
#   while not (done or truncated):
#     action, _states = model.predict(obs, deterministic=True)
#     obs, reward, done, truncated, info = env.step(action)
#     env.render()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 35       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 36       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 36       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 35       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 219      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.086    |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.34     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 35       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 247      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0171   |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.43     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 35       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 268      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.85     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 35       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 328      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.216    |
# |    n_updates        | 127      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 35       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 350      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.97     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 35       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 380      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.293    |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.14     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 35       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 430      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0811   |
# |    n_updates        | 229      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.9      |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 34       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 458      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.145    |
# |    n_updates        | 257      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 14>()
#       1 env = gym.make("highway-fast-v0")
#       2 model = DQN('MlpPolicy', env,
#       3               policy_kwargs=dict(net_arch=[256, 256]),
#       4               learning_rate=5e-4,
#    (...)
#      12               verbose=1,
#      13               tensorboard_log="highway_dqn/")
# ---> 14 model.learn(int(2e4))
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /opt/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:240, in AbstractEnv.step(self, action)
#     235     raise NotImplementedError(
#     236         "The road and vehicle must be initialized in the environment implementation"
#     237     )
#     239 self.time += 1 / self.config["policy_frequency"]
# --> 240 self._simulate(action)
#     242 obs = self.observation_type.observe()
#     243 reward = self._reward(action)
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/envs/common/abstract.py:271, in AbstractEnv._simulate(self, action)
#     259 if (
#     260     action is not None
#     261     and not self.config["manual_control"]
#    (...)
#     267     == 0
#     268 ):
#     269     self.action_type.act(action)
# --> 271 self.road.act()
#     272 self.road.step(1 / self.config["simulation_frequency"])
#     273 self.steps += 1
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/road/road.py:464, in Road.act(self)
#     462 """Decide the actions of each entity on the road."""
#     463 for vehicle in self.vehicles:
# --> 464     vehicle.act()
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/vehicle/behavior.py:109, in IDMVehicle.act(self, action)
#     107 if self.enable_lane_change:
#     108     self.change_lane_policy()
# --> 109 action["steering"] = self.steering_control(self.target_lane_index)
#     110 action["steering"] = np.clip(
#     111     action["steering"], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE
#     112 )
#     114 # Longitudinal: IDM
#
# File /opt/anaconda3/lib/python3.9/site-packages/highway_env/vehicle/controller.py:166, in ControlledVehicle.steering_control(self, target_lane_index)
#     163 lateral_speed_command = -self.KP_LATERAL * lane_coords[1]
#     164 # Lateral speed to heading
#     165 heading_command = np.arcsin(
# --> 166     np.clip(lateral_speed_command / utils.not_zero(self.speed), -1, 1)
#     167 )
#     168 heading_ref = lane_future_heading + np.clip(
#     169     heading_command, -np.pi / 4, np.pi / 4
#     170 )
#     171 # Heading control
#
# File <__array_function__ internals>:5, in clip(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:2115, in clip(a, a_min, a_max, out, **kwargs)
#    2046 @array_function_dispatch(_clip_dispatcher)
#    2047 def clip(a, a_min, a_max, out=None, **kwargs):
#    2048     """
#    2049     Clip (limit) the values in an array.
#    2050
#    (...)
#    2113
#    2114     """
# -> 2115     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:43, in _wrapit(obj, method, *args, **kwds)
#      41 except AttributeError:
#      42     wrap = None
# ---> 43 result = getattr(asarray(obj), method)(*args, **kwds)
#      44 if wrap:
#      45     if not isinstance(result, mu.ndarray):
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:137, in _clip(a, min, max, out, casting, **kwargs)
#     135     min = -float('inf')
#     136     using_deprecated_nan = True
# --> 137 if _clip_dep_is_scalar_nan(max):
#     138     max = float('inf')
#     139     using_deprecated_nan = True
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:97, in _clip_dep_is_scalar_nan(a)
#      95     return False
#      96 try:
# ---> 97     return um.isnan(a)
#      98 except TypeError:
#      99     return False
#
# KeyboardInterrupt:

# %% [markdown]
# # Compare with other model
#
#
# # See the results
